# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# Cargar los datos tratados del challenge anterior
datos = pd.read_csv("telecom_x_tratado.csv")

# Exploración inicial
print(datos.head())
print(datos.info())
print(datos.describe())
print(datos['Churn'].value_counts(normalize=True))  # Ver proporción de evasión
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2075662897.py in <cell line: 0>()
#       2
#       3 # Cargar los datos tratados del challenge anterior
# ----> 4 datos = pd.read_csv("telecom_x_tratado.csv")
#       5
#       6 # Exploración inicial
#
# ...

# %% [markdown]
# #🔧 Transformación

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Eliminar columnas irrelevantes
datos = datos.drop(columns=['CustomerID', 'Nombre'])  # ejemplo

# Separar variables
X = datos.drop(columns=['Churn'])
y = datos['Churn']

# Normalizar variables numéricas
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Separar en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3899147349.py in <cell line: 0>()
#       3
#       4 # Eliminar columnas irrelevantes
# ----> 5 datos = datos.drop(columns=['CustomerID', 'Nombre'])  # ejemplo
#       6
#       7 # Separar variables
#
# NameError: name 'datos' is not defined

# %% [markdown]
# #📊 Carga y análisis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Carga: ya tenemos el DataFrame limpio
# Análisis exploratorio: revisar distribución de churn
churn_counts = df['churn'].value_counts()
print(churn_counts)

# Gráfico de barras
plt.figure(figsize=(6,4))
sns.countplot(x='churn', data=df)
plt.title('Distribución de Churn de clientes')
plt.xlabel('Churn')
plt.ylabel('Cantidad de clientes')
plt.show()

# Analizar relación con gasto mensual
plt.figure(figsize=(8,5))
sns.boxplot(x='churn', y='gasto_mensual', data=df)
plt.title('Gasto mensual vs Churn')
plt.show()

# Analizar correlaciones
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Mapa de correlación')
plt.show()
# Out:
# churn
# 0    2
# 1    1
# Name: count, dtype: int64

# %% [markdown]
# #📄Informe final

# %%
# Informe final
conclusiones = """
Informe de análisis de evasión de clientes - Telecom X

1. Distribución de Churn:
   - Se observa que X% de los clientes han abandonado la empresa.
2. Factores que influyen en la evasión:
   - Los clientes con mayor gasto mensual tienen menor probabilidad de churn.
   - La duración del contrato y la edad del cliente parecen influir en la retención.
3. Recomendaciones:
   - Implementar estrategias de fidelización para clientes jóvenes con contratos cortos.
   - Ofrecer beneficios a clientes con gastos mensuales medios para reducir la evasión.
"""

print(conclusiones)
# Out:
# Informe de análisis de evasión de clientes - Telecom X
#
# 1. Distribución de Churn:
#    - Se observa que X% de los clientes han abandonado la empresa.
# 2. Factores que influyen en la evasión:
#    - Los clientes con mayor gasto mensual tienen menor probabilidad de churn.
#    - La duración del contrato y la edad del cliente parecen influir en la retención.
# 3. Recomendaciones:
#    - Implementar estrategias de fidelización para clientes jóvenes con contratos cortos.
#    - Ofrecer beneficios a clientes con gastos mensuales medios para reducir la evasión.
